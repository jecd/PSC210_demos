# %%
dddd

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
os.getcwd()
# Out:
# '/home/jordan/fMRI_demos'

# %%
basedir = os.getcwd()
subdir = os.path.join(basedir,"ds000114", "sub-01", "ses-test", "func")
print(subdir)
# Out:
# /home/jordan/fMRI_demos/ds000114/sub-01/ses-test/func

# %%
realignment = pd.read_table(subdir + "/sub-01_ses-test_task-fingerfootlips_bold_mc.nii.gz.par", sep="\s\s",names=[ "pitch", "roll", "yaw","x","y","z",])
framewise_rel = pd.read_table(subdir + "/sub-01_ses-test_task-fingerfootlips_bold_st_mc.nii.gz_rel.rms")
framewise_abs = pd.read_table(subdir + "/sub-01_ses-test_task-fingerfootlips_bold_st_mc.nii.gz_abs.rms")
# Out:
# /home/jordan/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.

# %%
realignment
# Out:
#         pitch      roll       yaw         x         y         z
# 0   -0.000941 -0.003663  0.007383  0.740141 -0.776819 -1.544380
# 1    0.007400 -0.003278  0.009947  0.389434 -0.066270 -0.296110
# 2    0.005617 -0.002179  0.010272  0.383003 -0.077538 -0.207704
# 3    0.006079 -0.002350  0.009594  0.356285 -0.049131 -0.222363
# 4    0.005532 -0.002292  0.009640  0.370073 -0.100598 -0.208983
# ..        ...       ...       ...       ...       ...       ...
# 179  0.011179  0.012840 -0.006228 -0.234945  0.182687  0.344013
# 180  0.010254  0.014274 -0.006262 -0.263409  0.083713  0.392309
# 181  0.009507  0.015204 -0.006942 -0.298818  0.095850  0.419184
# 182  0.009105  0.016110 -0.006935 -0.325620  0.110470  0.428405
# 183 -0.009324  0.021942 -0.004095 -0.300648  0.170439  0.183722
#
# [184 rows x 6 columns]

# %%
framewise_rel
# Out:
#      0.900446
# 0    0.087439
# 1    0.043177
# 2    0.029195
# 3    0.049304
# 4    0.036251
# ..        ...
# 177  0.077382
# 178  0.037703
# 179  0.095714
# 180  0.063338
# 181  0.928764
#
# [182 rows x 1 columns]

# %%
framewise_abs
# Out:
#       1.11999
# 0    0.927221
# 1    0.914649
# 2    0.894416
# 3    0.919200
# 4    0.908443
# ..        ...
# 178  1.034210
# 179  1.039260
# 180  1.047330
# 181  1.007920
# 182  0.947087
#
# [183 rows x 1 columns]

# %%
# rotations pitch roll yaw (radians)
for i in range(0,3):
    plt.plot(realignment.iloc[:,i])
plt.xlabel("volumes")
plt.ylabel("rotation (radians)")
plt.title("pitch,roll,yaw in radians")
plt.show()

# translation (xyz) mm
for i in range(4,6):
    plt.plot(realignment.iloc[:,i])
plt.xlabel("volumes")
plt.ylabel("tranlations (mm)")
plt.title("x,y,z in mm")
plt.show()

## framewise displacment # in mm
plt.plot(framewise_rel)
plt.plot(framewise_abs)
plt.xlabel("volumes")
plt.ylabel("displacement (mm)")
plt.title("framewise displacmenent (mm)")
plt.show()

# %%
#/home/jordan/fMRI_demos/ds000114/sub-01/ses-test/func/sub-01_ses-test_task-fingerfootlips_bold_st_mean_ref_mc.nii.gz
realignment = pd.read_table(subdir + "/sub-01_ses-test_task-fingerfootlips_bold_st_mean_ref_mc.nii.gz.par", sep="\s\s",names=[ "pitch", "roll", "yaw","x","y","z",])
framewise_rel = pd.read_table(subdir + "/sub-01_ses-test_task-fingerfootlips_bold_st_mean_ref_mc.nii.gz_rel.rms")
framewise_abs = pd.read_table(subdir + "/sub-01_ses-test_task-fingerfootlips_bold_st_mean_ref_mc.nii.gz_abs.rms")

# %%
# rotations pitch roll yaw (radians)
for i in range(0,3):
    plt.plot(realignment.iloc[:,i])
plt.xlabel("volumes")
plt.ylabel("rotation (radians)")
plt.title("pitch,roll,yaw in radians")
plt.show()

# translation (xyz) mm
for i in range(4,6):
    plt.plot(realignment.iloc[:,i])
plt.xlabel("volumes")
plt.ylabel("tranlations (mm)")
plt.title("x,y,z in mm")
plt.show()

## framewise displacment # in mm
plt.plot(framewise_rel)
plt.plot(framewise_abs)
plt.xlabel("volumes")
plt.ylabel("displacement (mm)")
plt.title("framewise displacmenent (mm)")
plt.show()

# %%
realignment = pd.read_table(subdir + "/bad_movement_bold_mc.nii.gz.par", sep="\s\s",names=[ "pitch", "roll", "yaw","x","y","z",])
framewise_rel = pd.read_table(subdir + "/bad_movement_bold_mc.nii.gz.par_rel.rms")
framewise_abs = pd.read_table(subdir + "/bad_movement_bold_mc.nii.gz.par_abs.rms")

# %%
# rotations pitch roll yaw (radians)
for i in range(0,3):
    plt.plot(realignment.iloc[:,i])
plt.xlabel("volumes")
plt.ylabel("rotation (radians)")
plt.title("pitch,roll,yaw in radians")
plt.show()

# translation (xyz) mm
for i in range(4,6):
    plt.plot(realignment.iloc[:,i])
plt.xlabel("volumes")
plt.ylabel("tranlations (mm)")
plt.title("x,y,z in mm")
plt.show()

## framewise displacment # in mm
plt.plot(framewise_rel)
plt.plot(framewise_abs)
plt.xlabel("volumes")
plt.ylabel("displacement (mm)")
plt.title("framewise displacmenent (mm)")
plt.show()

# %%
import nilearn
